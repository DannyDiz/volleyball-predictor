# %%
import pandas as pd

# %%
matches = pd.read_csv("VNL_mens_stats.csv", index_col=0)

# %%
matches.head()
# Out:
#    matchid      team   opponent result  sets won  sets lost  set1  set2  set3  \
# 1    16128  Bulgaria      China      L         2          3    20    25    21
# 2    16128     China   Bulgaria      W         3          2    25    21    25
# 3    16129     Japan       Iran      W         3          0    25    25    25
# 4    16129      Iran      Japan      L         0          3    16    22    19
# 5    16130     Italy  Argentina      L         0          3    22    23    18
#
#    set4  set5  attacks  blocks  serves  digs  receives  sets
# 1  25.0   NaN       52      10       4    39        83   106
# 2  20.0   5.0       56      12       8    32        84    98
# 3   NaN   NaN       47       4       4    48        45    83
# 4   NaN   NaN       29       6       3    26        61    78
# 5   NaN   NaN       37       2       2    51        56    87

# %%
matches.head()
# Out:
#    matchid      team   opponent result  sets won  sets lost  set1  set2  set3  \
# 1    16128  Bulgaria      China      L         2          3    20    25    21
# 2    16128     China   Bulgaria      W         3          2    25    21    25
# 3    16129     Japan       Iran      W         3          0    25    25    25
# 4    16129      Iran      Japan      L         0          3    16    22    19
# 5    16130     Italy  Argentina      L         0          3    22    23    18
#
#    set4  set5  attacks  blocks  serves  digs  receives  sets
# 1  25.0   NaN       52      10       4    39        83   106
# 2  20.0   5.0       56      12       8    32        84    98
# 3   NaN   NaN       47       4       4    48        45    83
# 4   NaN   NaN       29       6       3    26        61    78
# 5   NaN   NaN       37       2       2    51        56    87

# %%
matches.shape
# Out:
# (648, 17)

# %%
matches["team"].value_counts()
# Out:
# team
# Poland         45
# Japan          43
# Slovenia       43
# Italy          43
# France         41
# Brazil         41
# USA            39
# Argentina      38
# Canada         37
# Cuba           37
# Netherlands    36
# Bulgaria       36
# Serbia         36
# Iran           36
# Germany        36
# China          25
# Türkiye        24
# Ukraine        12
# Name: count, dtype: int64

# %%
matches.dtypes
# Out:
# matchid        int64
# team          object
# opponent      object
# result        object
# sets won       int64
# sets lost      int64
# set1           int64
# set2           int64
# set3           int64
# set4         float64
# set5         float64
# attacks        int64
# blocks         int64
# serves         int64
# digs           int64
# receives       int64
# sets           int64
# dtype: object

# %%
matches["opp_code"] = matches["opponent"].astype("category").cat.codes
matches["target"] = (matches["result"] == "W").astype("int")

# %%
matches
# Out:
#      matchid      team   opponent result  sets won  sets lost  set1  set2  \
# 1      16128  Bulgaria      China      L         2          3    20    25
# 2      16128     China   Bulgaria      W         3          2    25    21
# 3      16129     Japan       Iran      W         3          0    25    25
# 4      16129      Iran      Japan      L         0          3    16    22
# 5      16130     Italy  Argentina      L         0          3    22    23
# ..       ...       ...        ...    ...       ...        ...   ...   ...
# 644    21550  Slovenia      Italy      L         1          3    22    25
# 645    21551    Brazil   Slovenia      W         3          1    23    25
# 646    21551  Slovenia     Brazil      L         1          3    25    20
# 647    21552    Poland      Italy      W         3          0    25    25
# 648    21552     Italy     Poland      L         0          3    22    19
#
#      set3  set4  set5  attacks  blocks  serves  digs  receives  sets  \
# 1      21  25.0   NaN       52      10       4    39        83   106
# 2      25  20.0   5.0       56      12       8    32        84    98
# 3      25   NaN   NaN       47       4       4    48        45    83
# 4      19   NaN   NaN       29       6       3    26        61    78
# 5      18   NaN   NaN       37       2       2    51        56    87
# ..    ...   ...   ...      ...     ...     ...   ...       ...   ...
# 644    21  18.0   NaN       52       9       2    64        79   106
# 645    25  25.0   NaN       48      11       5    60        68   110
# 646    23  19.0   NaN       49       7       2    68        80   122
# 647    25   NaN   NaN       37      10       3    55        43    80
# 648    14   NaN   NaN       27       6       4    46        62    81
#
#      opp_code  target
# 1           4       0
# 2           2       1
# 3           8       1
# 4          10       0
# 5           0       0
# ..        ...     ...
# 644         9       0
# 645        14       1
# 646         1       0
# 647         9       1
# 648        12       0
#
# [648 rows x 19 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
# edit this line to change what subset of the data to train on
train = matches[matches["matchid"] < 21000]

# %%
# edit this line to change what subset of the data to test
test = matches[matches["matchid"] > 21000]

# %%
predictors = ["opp_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test["target"], preds)

# %%
acc
# Out:
# 0.646551724137931

# %%
combined = pd.DataFrame(dict(actual=test["target"], prediction=preds))

# %%
pd.crosstab(index=combined["actual"], columns=combined["prediction"])
# Out:
# prediction   0   1
# actual
# 0           78  38
# 1           44  72

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test["target"], preds)
# Out:
# 0.6545454545454545

# %%
# one dataframe for every team in the dataset
# rolling averages; "how did team A do in the previous x matches?" to predict how they will do on their next match
grouped_matches = matches.groupby("team")

# %%
# group = grouped_matches.get_group("Poland")

# %%
# group

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("matchid")
    rolling_stats = group[cols].rolling(3, closed='left').mean() # closed='left' means take the current match out when creating rolling averages
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols) # removes rows that have missing values
    return group

# %%
cols = ["sets won", "sets lost", "attacks", "blocks", "serves", "digs", "receives", "sets"]
new_cols = [f"{c}_rolling" for c in cols]

# %%
new_cols
# Out:
# ['sets won_rolling',
#  'sets lost_rolling',
#  'attacks_rolling',
#  'blocks_rolling',
#  'serves_rolling',
#  'digs_rolling',
#  'receives_rolling',
#  'sets_rolling']

# %%
rolling_averages(group, cols, new_cols)
# Out:
#      matchid    team     opponent result  sets won  sets lost  set1  set2  \
# 56     16155  Poland       Serbia      L         0          3    21    19
# 86     16170  Poland      Germany      W         3          2    25    22
# 98     16176  Poland  Netherlands      W         3          2    22    25
# 111    16183  Poland          USA      L         0          3    22    18
# 122    16188  Poland        Italy      W         3          1    25    28
# 139    16197  Poland     Slovenia      W         3          2    29    21
# 157    16206  Poland       Brazil      W         3          1    25    22
# 171    16213  Poland       Canada      W         3          0    25    25
# 186    16220  Poland        Japan      W         3          0    25    25
# 199    16227  Poland       Brazil      W         3          0    26    25
# 202    16228  Poland        Japan      W         3          1    19    28
# 207    16231  Poland          USA      W         3          1    25    24
# 220    18858  Poland          USA      W         3          0    25    25
# 228    18862  Poland       Canada      W         3          1    18    25
# 242    18869  Poland  Netherlands      W         3          0    30    25
# 262    18879  Poland     Slovenia      L         0          3    20    21
# 275    18886  Poland     Bulgaria      W         3          1    21    25
# 295    18896  Poland      Türkiye      W         3          0    25    25
# 308    18902  Poland        Japan      W         3          0    25    25
# 317    18907  Poland       Brazil      L         1          3    21    17
# 352    18924  Poland        Italy      W         3          0    25    25
# 372    18934  Poland    Argentina      W         3          0    25    25
# 386    18941  Poland       Serbia      W         3          2    25    21
# 396    18946  Poland         Cuba      W         3          0    25    25
# 403    18950  Poland       Brazil      W         3          1    18    25
# 409    18953  Poland       France      L         2          3    25    22
# 414    18955  Poland     Slovenia      W         3          0    26    25
# 417    21437  Poland  Netherlands      W         3          1    25    22
# 437    21447  Poland        Japan      W         3          1    27    25
# 462    21459  Poland      Türkiye      W         3          0    28    25
# 475    21466  Poland       Serbia      W         3          0    25    25
# 500    21478  Poland        Italy      L         2          3    17    25
# 530    21493  Poland       Canada      W         3          2    30    14
# 542    21499  Poland          USA      W         3          0    25    25
# 558    21507  Poland       Brazil      L         1          3    21    21
# 578    21517  Poland         Iran      W         3          2    25    23
# 590    21523  Poland         Cuba      L         1          3    25    19
# 612    21534  Poland     Bulgaria      L         2          3    25    22
# 630    21543  Poland       France      W         3          2    32    20
# 636    21546  Poland        Japan      W         3          0    25    26
# 642    21549  Poland       Brazil      W         3          0    28    25
# 647    21552  Poland        Italy      W         3          0    25    25
#
#      set3  set4  ...  opp_code  target  sets won_rolling  sets lost_rolling  \
# 56     14   NaN  ...        13       0          3.000000           1.666667
# 86     25  17.0  ...         7       1          2.000000           2.333333
# 98     18  25.0  ...        11       1          2.000000           2.333333
# 111    19   NaN  ...        16       0          2.000000           2.333333
# 122    18  25.0  ...         9       1          2.000000           2.333333
# 139    25  25.0  ...        14       1          2.000000           2.000000
# 157    25  25.0  ...         1       1          2.000000           2.000000
# 171    27   NaN  ...         3       1          3.000000           1.333333
# 186    25   NaN  ...        10       1          3.000000           1.000000
# 199    25   NaN  ...         1       1          3.000000           0.333333
# 202    25  25.0  ...        10       1          3.000000           0.000000
# 207    25  25.0  ...        16       1          3.000000           0.333333
# 220    26   NaN  ...        16       1          3.000000           0.666667
# 228    25  25.0  ...         3       1          3.000000           0.666667
# 242    25   NaN  ...        11       1          3.000000           0.666667
# 262    18   NaN  ...        14       0          3.000000           0.333333
# 275    25  25.0  ...         2       1          2.000000           1.333333
# 295    25   NaN  ...        15       1          2.000000           1.333333
# 308    25   NaN  ...        10       1          2.000000           1.333333
# 317    25  23.0  ...         1       0          3.000000           0.333333
# 352    25   NaN  ...         9       1          2.333333           1.000000
# 372    25   NaN  ...         0       1          2.333333           1.000000
# 386    25  22.0  ...        13       1          2.333333           1.000000
# 396    25   NaN  ...         5       1          3.000000           0.666667
# 403    25  25.0  ...         1       1          3.000000           0.666667
# 409    23  25.0  ...         6       0          3.000000           1.000000
# 414    25   NaN  ...        14       1          2.666667           1.333333
# 417    25  25.0  ...        11       1          2.666667           1.333333
# 437    18  39.0  ...        10       1          2.666667           1.333333
# 462    25   NaN  ...        15       1          3.000000           0.666667
# 475    25   NaN  ...        13       1          3.000000           0.666667
# 500    25  20.0  ...         9       0          3.000000           0.333333
# 530    25  25.0  ...         3       1          2.666667           1.000000
# 542    25   NaN  ...        16       1          2.666667           1.666667
# 558    25  26.0  ...         1       0          2.666667           1.666667
# 578    25  21.0  ...         8       1          2.333333           1.666667
# 590    21  24.0  ...         5       0          2.333333           1.666667
# 612    23  29.0  ...         2       0          1.666667           2.666667
# 630    25  23.0  ...         6       1          2.000000           2.666667
# 636    25   NaN  ...        10       1          2.000000           2.666667
# 642    25   NaN  ...         1       1          2.666667           1.666667
# 647    25   NaN  ...         9       1          3.000000           0.666667
#
#      attacks_rolling  blocks_rolling  serves_rolling  digs_rolling  \
# 56         58.666667       10.333333        7.666667     48.666667
# 86         53.000000        7.333333        6.000000     46.000000
# 98         50.666667        8.666667        6.000000     47.000000
# 111        50.666667        9.000000        4.666667     42.333333
# 122        48.333333        9.666667        4.333333     46.666667
# 139        47.333333        7.333333        4.666667     48.666667
# 157        50.333333        7.666667        5.000000     60.666667
# 171        58.333333        8.000000        5.333333     61.333333
# 186        53.333333        9.000000        4.000000     55.333333
# 199        46.000000        8.333333        4.666667     43.333333
# 202        40.666667        9.333333        6.666667     44.333333
# 207        47.333333        8.666667        7.000000     48.000000
# 220        52.333333        9.333333        6.666667     49.666667
# 228        53.333333        8.000000        6.333333     50.333333
# 242        52.333333        6.666667        7.666667     48.000000
# 262        47.000000        8.333333        7.666667     41.666667
# 275        46.333333        8.000000        5.666667     38.333333
# 295        42.333333        9.000000        5.333333     38.000000
# 308        40.333333        8.000000        5.000000     41.666667
# 317        41.333333       11.000000        4.666667     41.333333
# 352        41.666667       10.000000        3.333333     38.000000
# 372        43.666667        9.000000        2.000000     36.333333
# 386        43.666667        6.333333        2.666667     37.666667
# 396        49.000000        7.666667        5.000000     39.000000
# 403        48.333333        7.666667        5.333333     38.000000
# 409        51.333333        8.333333        6.666667     41.666667
# 414        47.666667       10.000000        4.333333     46.666667
# 417        45.000000       12.333333        6.000000     47.333333
# 437        47.333333       11.666667        5.666667     54.666667
# 462        52.000000       11.666667        4.666667     57.333333
# 475        52.666667        8.333333        3.666667     60.333333
# 500        48.000000        9.000000        2.666667     50.666667
# 530        47.000000        7.666667        4.000000     56.333333
# 542        55.333333       10.000000        4.333333     73.333333
# 558        54.333333        9.666667        5.000000     75.000000
# 578        49.666667       11.000000        4.666667     76.666667
# 590        50.000000        9.333333        6.666667     70.666667
# 612        51.000000        9.000000        6.333333     71.333333
# 630        54.333333        7.666667        6.333333     56.666667
# 636        53.333333        9.666667        4.333333     50.000000
# 642        50.333333       12.333333        4.333333     46.000000
# 647        44.333333       11.000000        5.666667     42.666667
#
#      receives_rolling  sets_rolling
# 56          76.000000    107.000000
# 86          72.000000    102.666667
# 98          72.333333    105.666667
# 111         73.000000     98.333333
# 122         71.000000     96.666667
# 139         68.333333     92.666667
# 157         74.666667    110.333333
# 171         78.333333    116.333333
# 186         73.333333    106.000000
# 199         57.000000     83.333333
# 202         51.666667     78.000000
# 207         57.333333     83.000000
# 220         66.666667     93.333333
# 228         65.333333     90.333333
# 242         65.666667     90.666667
# 262         62.333333     80.333333
# 275         67.000000     82.333333
# 295         61.333333     81.666667
# 308         53.000000     78.666667
# 317         47.333333     79.333333
# 352         52.333333     78.000000
# 372         56.333333     80.333333
# 386         56.666667     77.000000
# 396         59.666667     84.666667
# 403         57.000000     82.333333
# 409         64.666667     92.000000
# 414         63.666667     89.666667
# 417         66.333333     92.333333
# 437         67.666667    100.000000
# 462         71.666667    106.333333
# 475         71.666667    107.000000
# 500         64.333333     93.666667
# 530         65.666667    100.333333
# 542         77.666667    118.666667
# 558         77.666667    115.666667
# 578         73.666667    107.000000
# 590         70.333333    105.000000
# 612         77.000000    112.000000
# 630         78.000000    108.333333
# 636         81.000000    105.333333
# 642         71.333333     94.666667
# 647         61.333333     82.000000
#
# [42 rows x 27 columns]

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling
# Out:
#                matchid       team     opponent result  sets won  sets lost  \
# team
# Argentina 59     16157  Argentina  Netherlands      W         3          2
#           71     16163  Argentina     Slovenia      L         1          3
#           87     16171  Argentina       France      W         3          1
#           101    16178  Argentina     Bulgaria      W         3          0
#           110    16182  Argentina        Japan      L         2          3
# ...                ...        ...          ...    ...       ...        ...
# Ukraine   552    21504    Ukraine     Bulgaria      W         3          1
#           571    21514    Ukraine  Netherlands      W         3          2
#           587    21522    Ukraine        Italy      L         2          3
#           599    21528    Ukraine       Serbia      L         0          3
#           621    21539    Ukraine       Canada      L         1          3
#
#                set1  set2  set3  set4  ...  opp_code  target  \
# team                                   ...
# Argentina 59     34    25    25  20.0  ...        11       1
#           71     25    21    21  21.0  ...        14       0
#           87     22    26    25  25.0  ...         6       1
#           101    25    25    25   NaN  ...         2       1
#           110    18    22    33  25.0  ...        10       0
# ...             ...   ...   ...   ...  ...       ...     ...
# Ukraine   552    20    25    26  25.0  ...         2       1
#           571    25    20    20  26.0  ...        11       1
#           587    15    20    25  25.0  ...         9       0
#           599    22    19    17   NaN  ...        13       0
#           621    21    27    29  21.0  ...         3       0
#
#                sets won_rolling  sets lost_rolling  attacks_rolling  \
# team
# Argentina 59           2.666667           1.333333        51.666667
#           71           2.666667           2.000000        59.333333
#           87           2.333333           2.000000        57.333333
#           101          2.333333           2.000000        56.000000
#           110          2.333333           1.333333        49.000000
# ...                         ...                ...              ...
# Ukraine   552          2.000000           1.666667        45.333333
#           571          3.000000           1.000000        52.666667
#           587          3.000000           1.666667        58.666667
#           599          2.666667           2.000000        58.000000
#           621          1.666667           2.666667        51.666667
#
#                blocks_rolling  serves_rolling  digs_rolling  receives_rolling  \
# team
# Argentina 59         9.333333        3.666667     69.333333         71.666667
#           71        11.666667        5.000000     86.333333         84.000000
#           87         9.333333        4.333333     75.666667         79.000000
#           101        8.333333        4.666667     64.666667         78.000000
#           110        5.666667        4.333333     55.333333         64.333333
# ...                       ...             ...           ...               ...
# Ukraine   552        9.666667        4.333333     54.666667         62.333333
#           571       11.000000        5.333333     63.000000         66.666667
#           587        9.666667        6.000000     71.000000         80.000000
#           599        8.666667        5.333333     70.000000         84.333333
#           621        7.333333        4.000000     61.000000         82.000000
#
#                sets_rolling
# team
# Argentina 59     108.666667
#           71     128.666667
#           87     121.333333
#           101    116.000000
#           110     98.000000
# ...                     ...
# Ukraine   552     89.666667
#           571    104.333333
#           587    118.000000
#           599    122.000000
#           621    113.000000
#
# [594 rows x 27 columns]

# %%
matches_rolling = matches_rolling.droplevel('team')

# %%
matches_rolling
# Out:
#      matchid       team     opponent result  sets won  sets lost  set1  set2  \
# 59     16157  Argentina  Netherlands      W         3          2    34    25
# 71     16163  Argentina     Slovenia      L         1          3    25    21
# 87     16171  Argentina       France      W         3          1    22    26
# 101    16178  Argentina     Bulgaria      W         3          0    25    25
# 110    16182  Argentina        Japan      L         2          3    18    22
# ..       ...        ...          ...    ...       ...        ...   ...   ...
# 552    21504    Ukraine     Bulgaria      W         3          1    20    25
# 571    21514    Ukraine  Netherlands      W         3          2    25    20
# 587    21522    Ukraine        Italy      L         2          3    15    20
# 599    21528    Ukraine       Serbia      L         0          3    22    19
# 621    21539    Ukraine       Canada      L         1          3    21    27
#
#      set3  set4  ...  opp_code  target  sets won_rolling  sets lost_rolling  \
# 59     25  20.0  ...        11       1          2.666667           1.333333
# 71     21  21.0  ...        14       0          2.666667           2.000000
# 87     25  25.0  ...         6       1          2.333333           2.000000
# 101    25   NaN  ...         2       1          2.333333           2.000000
# 110    33  25.0  ...        10       0          2.333333           1.333333
# ..    ...   ...  ...       ...     ...               ...                ...
# 552    26  25.0  ...         2       1          2.000000           1.666667
# 571    20  26.0  ...        11       1          3.000000           1.000000
# 587    25  25.0  ...         9       0          3.000000           1.666667
# 599    17   NaN  ...        13       0          2.666667           2.000000
# 621    29  21.0  ...         3       0          1.666667           2.666667
#
#      attacks_rolling  blocks_rolling  serves_rolling  digs_rolling  \
# 59         51.666667        9.333333        3.666667     69.333333
# 71         59.333333       11.666667        5.000000     86.333333
# 87         57.333333        9.333333        4.333333     75.666667
# 101        56.000000        8.333333        4.666667     64.666667
# 110        49.000000        5.666667        4.333333     55.333333
# ..               ...             ...             ...           ...
# 552        45.333333        9.666667        4.333333     54.666667
# 571        52.666667       11.000000        5.333333     63.000000
# 587        58.666667        9.666667        6.000000     71.000000
# 599        58.000000        8.666667        5.333333     70.000000
# 621        51.666667        7.333333        4.000000     61.000000
#
#      receives_rolling  sets_rolling
# 59          71.666667    108.666667
# 71          84.000000    128.666667
# 87          79.000000    121.333333
# 101         78.000000    116.000000
# 110         64.333333     98.000000
# ..                ...           ...
# 552         62.333333     89.666667
# 571         66.666667    104.333333
# 587         80.000000    118.000000
# 599         84.333333    122.000000
# 621         82.000000    113.000000
#
# [594 rows x 27 columns]

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
matches_rolling
# Out:
#      matchid       team     opponent result  sets won  sets lost  set1  set2  \
# 0      16157  Argentina  Netherlands      W         3          2    34    25
# 1      16163  Argentina     Slovenia      L         1          3    25    21
# 2      16171  Argentina       France      W         3          1    22    26
# 3      16178  Argentina     Bulgaria      W         3          0    25    25
# 4      16182  Argentina        Japan      L         2          3    18    22
# ..       ...        ...          ...    ...       ...        ...   ...   ...
# 589    21504    Ukraine     Bulgaria      W         3          1    20    25
# 590    21514    Ukraine  Netherlands      W         3          2    25    20
# 591    21522    Ukraine        Italy      L         2          3    15    20
# 592    21528    Ukraine       Serbia      L         0          3    22    19
# 593    21539    Ukraine       Canada      L         1          3    21    27
#
#      set3  set4  ...  opp_code  target  sets won_rolling  sets lost_rolling  \
# 0      25  20.0  ...        11       1          2.666667           1.333333
# 1      21  21.0  ...        14       0          2.666667           2.000000
# 2      25  25.0  ...         6       1          2.333333           2.000000
# 3      25   NaN  ...         2       1          2.333333           2.000000
# 4      33  25.0  ...        10       0          2.333333           1.333333
# ..    ...   ...  ...       ...     ...               ...                ...
# 589    26  25.0  ...         2       1          2.000000           1.666667
# 590    20  26.0  ...        11       1          3.000000           1.000000
# 591    25  25.0  ...         9       0          3.000000           1.666667
# 592    17   NaN  ...        13       0          2.666667           2.000000
# 593    29  21.0  ...         3       0          1.666667           2.666667
#
#      attacks_rolling  blocks_rolling  serves_rolling  digs_rolling  \
# 0          51.666667        9.333333        3.666667     69.333333
# 1          59.333333       11.666667        5.000000     86.333333
# 2          57.333333        9.333333        4.333333     75.666667
# 3          56.000000        8.333333        4.666667     64.666667
# 4          49.000000        5.666667        4.333333     55.333333
# ..               ...             ...             ...           ...
# 589        45.333333        9.666667        4.333333     54.666667
# 590        52.666667       11.000000        5.333333     63.000000
# 591        58.666667        9.666667        6.000000     71.000000
# 592        58.000000        8.666667        5.333333     70.000000
# 593        51.666667        7.333333        4.000000     61.000000
#
#      receives_rolling  sets_rolling
# 0           71.666667    108.666667
# 1           84.000000    128.666667
# 2           79.000000    121.333333
# 3           78.000000    116.000000
# 4           64.333333     98.000000
# ..                ...           ...
# 589         62.333333     89.666667
# 590         66.666667    104.333333
# 591         80.000000    118.000000
# 592         84.333333    122.000000
# 593         82.000000    113.000000
#
# [594 rows x 27 columns]

# %%
def make_predictions(data, predictors):
    train = data[data["matchid"] < 21000]
    test = data[data["matchid"] > 21000]
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    precision = precision_score(test["target"], preds)
    return combined, precision

# %%
combined, precision = make_predictions(matches_rolling, predictors + new_cols)

# %%
precision
# Out:
# 0.5419847328244275

# %%
combined
# Out:
#      actual  predicted
# 23        1          0
# 24        1          1
# 25        0          1
# 26        0          0
# 27        1          1
# ..      ...        ...
# 589       1          1
# 590       1          1
# 591       0          1
# 592       0          1
# 593       0          1
#
# [229 rows x 2 columns]

# %%
combined = combined.merge(matches_rolling[["matchid", "team", "opponent", "result"]], left_index=True, right_index=True)

# %%
combined
# Out:
#      actual  predicted  matchid       team     opponent result
# 23        1          0    21442  Argentina       France      W
# 24        1          1    21450  Argentina       Canada      W
# 25        0          1    21454  Argentina     Bulgaria      L
# 26        0          0    21468  Argentina        Italy      L
# 27        1          1    21476  Argentina  Netherlands      W
# ..      ...        ...      ...        ...          ...    ...
# 589       1          1    21504    Ukraine     Bulgaria      W
# 590       1          1    21514    Ukraine  Netherlands      W
# 591       0          1    21522    Ukraine        Italy      L
# 592       0          1    21528    Ukraine       Serbia      L
# 593       0          1    21539    Ukraine       Canada      L
#
# [229 rows x 6 columns]

# %%
merged = combined.merge(combined, left_on=["matchid", "team"], right_on=["matchid", "opponent"])

# %%
merged
# Out:
#      actual_x  predicted_x  matchid     team_x   opponent_x result_x  \
# 0           1            0    21442  Argentina       France        W
# 1           1            1    21450  Argentina       Canada        W
# 2           0            1    21454  Argentina     Bulgaria        L
# 3           0            0    21468  Argentina        Italy        L
# 4           1            1    21476  Argentina  Netherlands        W
# ..        ...          ...      ...        ...          ...      ...
# 221         1            1    21504    Ukraine     Bulgaria        W
# 222         1            1    21514    Ukraine  Netherlands        W
# 223         0            1    21522    Ukraine        Italy        L
# 224         0            1    21528    Ukraine       Serbia        L
# 225         0            1    21539    Ukraine       Canada        L
#
#      actual_y  predicted_y       team_y opponent_y result_y
# 0           0            0       France  Argentina        L
# 1           0            0       Canada  Argentina        L
# 2           1            0     Bulgaria  Argentina        W
# 3           1            1        Italy  Argentina        W
# 4           0            0  Netherlands  Argentina        L
# ..        ...          ...          ...        ...      ...
# 221         0            0     Bulgaria    Ukraine        L
# 222         0            1  Netherlands    Ukraine        L
# 223         1            1        Italy    Ukraine        W
# 224         1            0       Serbia    Ukraine        W
# 225         1            0       Canada    Ukraine        W
#
# [226 rows x 11 columns]

# %%
merged[(merged["predicted_x"] == 1) & (merged["predicted_y"] == 0)]["actual_x"].value_counts()
# Out:
# actual_x
# 1    37
# 0    26
# Name: count, dtype: int64

# %%
37/(37+26)
# Out:
# 0.5873015873015873
