# %%
##### Retrospective evaluation #####

# %%
import pandas as pd
import numpy as np

# %%
np.set_printoptions(legacy='1.25')

# %%
matches = pd.read_csv("mens_stats.csv", index_col=0)

# %%
matches.head()
# Out:
#    matchid       team   opponent result  sets won  sets lost  set1  set2  \
# 1    11700     France   Bulgaria      W         3          0    27    25
# 2    11700   Bulgaria     France      L         0          3    25    21
# 3    11701    Germany  Australia      W         3          0    25    25
# 4    11701  Australia    Germany      L         0          3    19    18
# 5    11702      Japan       Iran      W         3          0    25    25
#
#    set3  set4  set5  attacks  blocks  serves  digs  receives  sets
# 1    25   NaN   NaN       39       7       4    13        54    74
# 2    23   NaN   NaN       36       5       4    11        56    78
# 3    25   NaN   NaN       42       5       5    34        40    71
# 4    16   NaN   NaN       28       3       0    26        53    60
# 5    26   NaN   NaN       45       7       2    11        50    94

# %%
# matches.shape
# matches["team"].value_counts()
# matches.dtypes

# %%
matches["opp_code"] = matches["opponent"].astype("category").cat.codes
matches["target"] = (matches["result"] == "W").astype("int")

# %%
matches
# Out:
#       matchid       team   opponent result  sets won  sets lost  set1  set2  \
# 1       11700     France   Bulgaria      W         3          0    27    25
# 2       11700   Bulgaria     France      L         0          3    25    21
# 3       11701    Germany  Australia      W         3          0    25    25
# 4       11701  Australia    Germany      L         0          3    19    18
# 5       11702      Japan       Iran      W         3          0    25    25
# ...       ...        ...        ...    ...       ...        ...   ...   ...
# 1200    21550   Slovenia      Italy      L         1          3    22    25
# 1201    21551     Brazil   Slovenia      W         3          1    23    25
# 1202    21551   Slovenia     Brazil      L         1          3    25    20
# 1203    21552     Poland      Italy      W         3          0    25    25
# 1204    21552      Italy     Poland      L         0          3    22    19
#
#       set3  set4  set5  attacks  blocks  serves  digs  receives  sets  \
# 1       25   NaN   NaN       39       7       4    13        54    74
# 2       23   NaN   NaN       36       5       4    11        56    78
# 3       25   NaN   NaN       42       5       5    34        40    71
# 4       16   NaN   NaN       28       3       0    26        53    60
# 5       26   NaN   NaN       45       7       2    11        50    94
# ...    ...   ...   ...      ...     ...     ...   ...       ...   ...
# 1200    21  18.0   NaN       52       9       2    64        79   106
# 1201    25  25.0   NaN       48      11       5    60        68   110
# 1202    23  19.0   NaN       49       7       2    68        80   122
# 1203    25   NaN   NaN       37      10       3    55        43    80
# 1204    14   NaN   NaN       27       6       4    46        62    81
#
#       opp_code  target
# 1            3       1
# 2            9       0
# 3            1       1
# 4           10       0
# 5           11       1
# ...        ...     ...
# 1200        12       0
# 1201        21       1
# 1202         2       0
# 1203        12       1
# 1204        16       0
#
# [1204 rows x 19 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# play around with parameters based on dataset
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
# edit this line to change what subset of the data to train on
train = matches[matches["matchid"] < 21000]
# edit this line to change what subset of the data to test
test = matches[matches["matchid"] > 21000]

# %%
predictors = ["opp_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test["target"], preds)

# %%
acc
# Out:
# 0.6206896551724138

# %%
combined = pd.DataFrame(dict(actual=test["target"], prediction=preds))
pd.crosstab(index=combined["actual"], columns=combined["prediction"])
# Out:
# prediction   0   1
# actual
# 0           75  41
# 1           47  69

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test["target"], preds)
# Out:
# 0.6272727272727273

# %%
# one dataframe for every team in the dataset
# rolling averages; "how did team A do in the previous x matches?" to predict how they will do on their next match
grouped_matches = matches.groupby("team")

# %%
# group = grouped_matches.get_group("Poland")
# group

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("matchid")
    rolling_stats = group[cols].rolling(5, closed='left').mean() # closed='left' means take the current match out when creating rolling averages
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols) # removes rows that have missing values
    return group

# %%
cols = ["sets won", "sets lost", "attacks", "blocks", "serves", "digs", "receives", "sets"]
new_cols = [f"{c}_rolling" for c in cols]
new_cols
# Out:
# ['sets won_rolling',
#  'sets lost_rolling',
#  'attacks_rolling',
#  'blocks_rolling',
#  'serves_rolling',
#  'digs_rolling',
#  'receives_rolling',
#  'sets_rolling']

# %%
# rolling_averages(group, cols, new_cols)

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling
# Out:
#                 matchid       team     opponent result  sets won  sets lost  \
# team
# Argentina 82      11740  Argentina  Netherlands      W         3          0
#           105     11752  Argentina        Italy      L         0          3
#           119     11759  Argentina    Australia      W         3          0
#           134     11766  Argentina        Japan      W         3          1
#           149     11774  Argentina     Bulgaria      W         3          1
# ...                 ...        ...          ...    ...       ...        ...
# Ukraine   1108    21504    Ukraine     Bulgaria      W         3          1
#           1127    21514    Ukraine  Netherlands      W         3          2
#           1143    21522    Ukraine        Italy      L         2          3
#           1155    21528    Ukraine       Serbia      L         0          3
#           1177    21539    Ukraine       Canada      L         1          3
#
#                 set1  set2  set3  set4  ...  opp_code  target  \
# team                                    ...
# Argentina 82      25    25    25   NaN  ...        15       1
#           105     28    21    20   NaN  ...        12       0
#           119     25    25    25   NaN  ...         1       1
#           134     30    25    25  25.0  ...        13       1
#           149     25    16    25  25.0  ...         3       1
# ...              ...   ...   ...   ...  ...       ...     ...
# Ukraine   1108    20    25    26  25.0  ...         3       1
#           1127    25    20    20  26.0  ...        15       1
#           1143    15    20    25  25.0  ...        12       0
#           1155    22    19    17   NaN  ...        20       0
#           1177    21    27    29  21.0  ...         5       0
#
#                 sets won_rolling  sets lost_rolling  attacks_rolling  \
# team
# Argentina 82                 0.8                2.8             40.6
#           105                1.4                2.2             41.6
#           119                1.4                2.2             43.8
#           134                1.8                1.6             46.4
#           149                1.8                1.4             44.6
# ...                          ...                ...              ...
# Ukraine   1108               2.0                2.2             52.4
#           1127               2.2                1.8             51.2
#           1143               2.4                1.6             50.8
#           1155               2.8                1.6             54.8
#           1177               2.2                2.2             54.2
#
#                 blocks_rolling  serves_rolling  digs_rolling  \
# team
# Argentina 82               8.4             1.6          46.0
#           105              7.8             1.4          47.2
#           119              8.6             1.2          48.2
#           134              8.0             2.0          46.8
#           149              8.2             2.8          49.2
# ...                        ...             ...           ...
# Ukraine   1108            10.8             5.6          57.0
#           1127            10.8             4.8          57.8
#           1143             9.2             4.6          60.8
#           1155             9.6             5.4          64.8
#           1177             9.0             5.0          66.2
#
#                 receives_rolling  sets_rolling
# team
# Argentina 82                69.8          92.4
#           105               65.8          93.4
#           119               66.6          99.6
#           134               62.0          96.6
#           149               59.2          94.8
# ...                          ...           ...
# Ukraine   1108              74.8         103.4
#           1127              72.4         104.4
#           1143              70.0         101.8
#           1155              75.4         111.0
#           1177              79.8         115.4
#
# [1081 rows x 27 columns]

# %%
matches_rolling = matches_rolling.droplevel('team')
matches_rolling
# Out:
#       matchid       team     opponent result  sets won  sets lost  set1  set2  \
# 82      11740  Argentina  Netherlands      W         3          0    25    25
# 105     11752  Argentina        Italy      L         0          3    28    21
# 119     11759  Argentina    Australia      W         3          0    25    25
# 134     11766  Argentina        Japan      W         3          1    30    25
# 149     11774  Argentina     Bulgaria      W         3          1    25    16
# ...       ...        ...          ...    ...       ...        ...   ...   ...
# 1108    21504    Ukraine     Bulgaria      W         3          1    20    25
# 1127    21514    Ukraine  Netherlands      W         3          2    25    20
# 1143    21522    Ukraine        Italy      L         2          3    15    20
# 1155    21528    Ukraine       Serbia      L         0          3    22    19
# 1177    21539    Ukraine       Canada      L         1          3    21    27
#
#       set3  set4  ...  opp_code  target  sets won_rolling  sets lost_rolling  \
# 82      25   NaN  ...        15       1               0.8                2.8
# 105     20   NaN  ...        12       0               1.4                2.2
# 119     25   NaN  ...         1       1               1.4                2.2
# 134     25  25.0  ...        13       1               1.8                1.6
# 149     25  25.0  ...         3       1               1.8                1.4
# ...    ...   ...  ...       ...     ...               ...                ...
# 1108    26  25.0  ...         3       1               2.0                2.2
# 1127    20  26.0  ...        15       1               2.2                1.8
# 1143    25  25.0  ...        12       0               2.4                1.6
# 1155    17   NaN  ...        20       0               2.8                1.6
# 1177    29  21.0  ...         5       0               2.2                2.2
#
#       attacks_rolling  blocks_rolling  serves_rolling  digs_rolling  \
# 82               40.6             8.4             1.6          46.0
# 105              41.6             7.8             1.4          47.2
# 119              43.8             8.6             1.2          48.2
# 134              46.4             8.0             2.0          46.8
# 149              44.6             8.2             2.8          49.2
# ...               ...             ...             ...           ...
# 1108             52.4            10.8             5.6          57.0
# 1127             51.2            10.8             4.8          57.8
# 1143             50.8             9.2             4.6          60.8
# 1155             54.8             9.6             5.4          64.8
# 1177             54.2             9.0             5.0          66.2
#
#       receives_rolling  sets_rolling
# 82                69.8          92.4
# 105               65.8          93.4
# 119               66.6          99.6
# 134               62.0          96.6
# 149               59.2          94.8
# ...                ...           ...
# 1108              74.8         103.4
# 1127              72.4         104.4
# 1143              70.0         101.8
# 1155              75.4         111.0
# 1177              79.8         115.4
#
# [1081 rows x 27 columns]

# %%
matches_rolling.index = range(matches_rolling.shape[0])
matches_rolling
# Out:
#       matchid       team     opponent result  sets won  sets lost  set1  set2  \
# 0       11740  Argentina  Netherlands      W         3          0    25    25
# 1       11752  Argentina        Italy      L         0          3    28    21
# 2       11759  Argentina    Australia      W         3          0    25    25
# 3       11766  Argentina        Japan      W         3          1    30    25
# 4       11774  Argentina     Bulgaria      W         3          1    25    16
# ...       ...        ...          ...    ...       ...        ...   ...   ...
# 1076    21504    Ukraine     Bulgaria      W         3          1    20    25
# 1077    21514    Ukraine  Netherlands      W         3          2    25    20
# 1078    21522    Ukraine        Italy      L         2          3    15    20
# 1079    21528    Ukraine       Serbia      L         0          3    22    19
# 1080    21539    Ukraine       Canada      L         1          3    21    27
#
#       set3  set4  ...  opp_code  target  sets won_rolling  sets lost_rolling  \
# 0       25   NaN  ...        15       1               0.8                2.8
# 1       20   NaN  ...        12       0               1.4                2.2
# 2       25   NaN  ...         1       1               1.4                2.2
# 3       25  25.0  ...        13       1               1.8                1.6
# 4       25  25.0  ...         3       1               1.8                1.4
# ...    ...   ...  ...       ...     ...               ...                ...
# 1076    26  25.0  ...         3       1               2.0                2.2
# 1077    20  26.0  ...        15       1               2.2                1.8
# 1078    25  25.0  ...        12       0               2.4                1.6
# 1079    17   NaN  ...        20       0               2.8                1.6
# 1080    29  21.0  ...         5       0               2.2                2.2
#
#       attacks_rolling  blocks_rolling  serves_rolling  digs_rolling  \
# 0                40.6             8.4             1.6          46.0
# 1                41.6             7.8             1.4          47.2
# 2                43.8             8.6             1.2          48.2
# 3                46.4             8.0             2.0          46.8
# 4                44.6             8.2             2.8          49.2
# ...               ...             ...             ...           ...
# 1076             52.4            10.8             5.6          57.0
# 1077             51.2            10.8             4.8          57.8
# 1078             50.8             9.2             4.6          60.8
# 1079             54.8             9.6             5.4          64.8
# 1080             54.2             9.0             5.0          66.2
#
#       receives_rolling  sets_rolling
# 0                 69.8          92.4
# 1                 65.8          93.4
# 2                 66.6          99.6
# 3                 62.0          96.6
# 4                 59.2          94.8
# ...                ...           ...
# 1076              74.8         103.4
# 1077              72.4         104.4
# 1078              70.0         101.8
# 1079              75.4         111.0
# 1080              79.8         115.4
#
# [1081 rows x 27 columns]

# %%
def make_predictions(data, predictors):
    train = data[data["matchid"] < 21000]
    test = data[data["matchid"] > 21000]
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    precision = precision_score(test["target"], preds)
    return combined, precision

# %%
combined, precision = make_predictions(matches_rolling, predictors + new_cols)

# %%
precision
# Out:
# 0.5522388059701493

# %%
combined
# Out:
#       actual  predicted
# 53         1          0
# 54         1          1
# 55         0          1
# 56         0          0
# 57         1          0
# ...      ...        ...
# 1076       1          1
# 1077       1          1
# 1078       0          1
# 1079       0          1
# 1080       0          1
#
# [232 rows x 2 columns]

# %%
combined = combined.merge(matches_rolling[["matchid", "team", "opponent", "result"]], left_index=True, right_index=True)
combined
# Out:
#       actual  predicted  matchid       team     opponent result
# 53         1          0    21442  Argentina       France      W
# 54         1          1    21450  Argentina       Canada      W
# 55         0          1    21454  Argentina     Bulgaria      L
# 56         0          0    21468  Argentina        Italy      L
# 57         1          0    21476  Argentina  Netherlands      W
# ...      ...        ...      ...        ...          ...    ...
# 1076       1          1    21504    Ukraine     Bulgaria      W
# 1077       1          1    21514    Ukraine  Netherlands      W
# 1078       0          1    21522    Ukraine        Italy      L
# 1079       0          1    21528    Ukraine       Serbia      L
# 1080       0          1    21539    Ukraine       Canada      L
#
# [232 rows x 6 columns]

# %%
merged = combined.merge(combined, left_on=["matchid", "team"], right_on=["matchid", "opponent"])
merged
# Out:
#      actual_x  predicted_x  matchid     team_x   opponent_x result_x  \
# 0           1            0    21442  Argentina       France        W
# 1           1            1    21450  Argentina       Canada        W
# 2           0            1    21454  Argentina     Bulgaria        L
# 3           0            0    21468  Argentina        Italy        L
# 4           1            0    21476  Argentina  Netherlands        W
# ..        ...          ...      ...        ...          ...      ...
# 227         1            1    21504    Ukraine     Bulgaria        W
# 228         1            1    21514    Ukraine  Netherlands        W
# 229         0            1    21522    Ukraine        Italy        L
# 230         0            1    21528    Ukraine       Serbia        L
# 231         0            1    21539    Ukraine       Canada        L
#
#      actual_y  predicted_y       team_y opponent_y result_y
# 0           0            1       France  Argentina        L
# 1           0            0       Canada  Argentina        L
# 2           1            0     Bulgaria  Argentina        W
# 3           1            1        Italy  Argentina        W
# 4           0            1  Netherlands  Argentina        L
# ..        ...          ...          ...        ...      ...
# 227         0            1     Bulgaria    Ukraine        L
# 228         0            0  Netherlands    Ukraine        L
# 229         1            1        Italy    Ukraine        W
# 230         1            0       Serbia    Ukraine        W
# 231         1            1       Canada    Ukraine        W
#
# [232 rows x 11 columns]

# %%
merged[(merged["predicted_x"] == 1) & (merged["predicted_y"] == 0)]["actual_x"].value_counts()
# Out:
# actual_x
# 1    39
# 0    25
# Name: count, dtype: int64

# %%
##### Predictive Tool #####

# %%
matches
# Out:
#       matchid       team   opponent result  sets won  sets lost  set1  set2  \
# 1       11700     France   Bulgaria      W         3          0    27    25
# 2       11700   Bulgaria     France      L         0          3    25    21
# 3       11701    Germany  Australia      W         3          0    25    25
# 4       11701  Australia    Germany      L         0          3    19    18
# 5       11702      Japan       Iran      W         3          0    25    25
# ...       ...        ...        ...    ...       ...        ...   ...   ...
# 1200    21550   Slovenia      Italy      L         1          3    22    25
# 1201    21551     Brazil   Slovenia      W         3          1    23    25
# 1202    21551   Slovenia     Brazil      L         1          3    25    20
# 1203    21552     Poland      Italy      W         3          0    25    25
# 1204    21552      Italy     Poland      L         0          3    22    19
#
#       set3  set4  set5  attacks  blocks  serves  digs  receives  sets  \
# 1       25   NaN   NaN       39       7       4    13        54    74
# 2       23   NaN   NaN       36       5       4    11        56    78
# 3       25   NaN   NaN       42       5       5    34        40    71
# 4       16   NaN   NaN       28       3       0    26        53    60
# 5       26   NaN   NaN       45       7       2    11        50    94
# ...    ...   ...   ...      ...     ...     ...   ...       ...   ...
# 1200    21  18.0   NaN       52       9       2    64        79   106
# 1201    25  25.0   NaN       48      11       5    60        68   110
# 1202    23  19.0   NaN       49       7       2    68        80   122
# 1203    25   NaN   NaN       37      10       3    55        43    80
# 1204    14   NaN   NaN       27       6       4    46        62    81
#
#       opp_code  target
# 1            3       1
# 2            9       0
# 3            1       1
# 4           10       0
# 5           11       1
# ...        ...     ...
# 1200        12       0
# 1201        21       1
# 1202         2       0
# 1203        12       1
# 1204        16       0
#
# [1204 rows x 19 columns]

# %%
# compute rolling averages of stats grouped by team
def add_rolling_averages(df, predictors, window=5):
    df_sorted = df.sort_values(["team", "matchid"])  # sort
    for col in predictors:
        df_sorted[col + "_rolling"] = (
            df_sorted.groupby("team")[col]
            .transform(lambda x: x.rolling(window, min_periods=1).mean().shift(1))
        )
    return df_sorted

# %%
# merge by matchid and merge the two team rows into one row
def build_matchup_data(df, predictors):
    df = df.copy()
    df["target"] = (df["result"] == "W").astype(int)

    winners = df[df["target"] == 1].copy()
    losers = df[df["target"] == 0].copy()

    matchups = winners.merge(losers, on="matchid", suffixes=("_win", "_lose"))

    # Generate two rows per matchup
    rows = []

    for _, row in matchups.iterrows():
        feat_win = {col + "_diff": row[col + "_rolling_win"] - row[col + "_rolling_lose"] for col in predictors}
        feat_lose = {col + "_diff": row[col + "_rolling_lose"] - row[col + "_rolling_win"] for col in predictors}

        rows.append((feat_win, 1))  # winner perspective
        rows.append((feat_lose, 0))  # loser perspective

    X = pd.DataFrame([r[0] for r in rows])
    y = [r[1] for r in rows]

    return X, y, matchups

# %%
predictors = ["attacks", "blocks", "serves", "digs", "receives", "sets", "sets won", "sets lost"]

# %%
# add rolling averages
matches_with_roll = add_rolling_averages(matches, predictors)

# %%
# build training data
X, y, matchups = build_matchup_data(matches_with_roll, predictors)

# %%
# train model
rf = RandomForestClassifier(n_estimators=200, min_samples_split=5, random_state=1)

# %%
rf.fit(X, y)
# Out:
# RandomForestClassifier(min_samples_split=5, n_estimators=200, random_state=1)

# %%
def predict_match(team_a, team_b, df, model, predictors):
    team_a_row = df[df["team"] == team_a].sort_values("matchid").iloc[-1]
    team_b_row = df[df["team"] == team_b].sort_values("matchid").iloc[-1]

    # Build both feature differences
    features_a = [team_a_row[col + "_rolling"] - team_b_row[col + "_rolling"] for col in predictors]
    features_b = [team_b_row[col + "_rolling"] - team_a_row[col + "_rolling"] for col in predictors]

    # Get both probabilities
    prob_a = model.predict_proba([features_a])[0][1]  # prob team_a wins
    prob_b = model.predict_proba([features_b])[0][1]  # prob team_b wins

    # Pick the higher-confidence outcome
    if prob_a > prob_b:
        return team_a, [1-prob_a, prob_a]
    else:
        return team_b, [1-prob_b, prob_b]

# %%
winner, prob = predict_match("Italy", "Poland", matches_with_roll, rf, predictors)
prob = [round(p, 3) for p in prob]

# %%
prob
# Out:
# [0.452, 0.548]

# %%
print(f"Predicted winner: {winner}, Probabilities: {prob}")
# Out:
# Predicted winner: Poland, Probabilities: [0.452, 0.548]
